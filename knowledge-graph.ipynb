# %%
import numpy as np 
import pandas as pd # data processing, CSV file

# %%
# pip install -U spacy && python -m spacy download en

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
nlp=spacy.load('en_core_web_sm')

# %% [markdown]
# # Building a Knowledge Graph from Text Data

# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %% [markdown]
# Importing the dataset

# %%
# import the dataset
candidate_sentences = pd.read_csv("wiki_sentences_v2.csv")
candidate_sentences.shape
# Out:
# (4318, 1)

# %%
candidate_sentences['sentence'].sample(5)
# Out:
# 3545                           this was a landmark film of the odia film industry.
# 1853    however, because of the additive process, the picture will be much darker.
# 499                             the filmfare awards were first introduced in 1954.
# 1058                                           most scripts specify some blocking.
# 2567              the canal  is a 1979 turkish drama film directed by erden kıral.
# Name: sentence, dtype: object

# %% [markdown]
# A function to extract the subject and the object (entities) from a sentence

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %% [markdown]
# Testing the function on a simple sentence

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %% [markdown]
# Using the function to extract the entity pairs for all the sentences in the dataset

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["sentence"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 4318/4318 [00:21<00:00, 199.74it/s]

# %%
entity_pairs[10:20]
# Out:
# [['we', 'tests'],
#  ['m', 'international sales rights'],
#  ['canadian musician robbie robertson', 'soundtrack'],
#  ['it', 'existing music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['military  forces', 'arrest'],
#  ['train', 'vuk'],
#  ['', 'selene gallio'],
#  ['singer', 'sequel']]

# %% [markdown]
# Relationships / Predicates Extraction

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", [pattern]) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %% [markdown]
# Testing the function on a simple sentence

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %% [markdown]
# Using the function to extract all the predicates from the dataset

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 4318/4318 [00:22<00:00, 192.39it/s]

# %% [markdown]
# Predicates extracted

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# is               364
# was              299
# released on       88
# include           72
# are               70
# were              65
# released          41
# 's                37
# composed by       32
# became            31
# have              31
# has               30
# become            28
# released in       27
# included          23
# called            21
# produced          21
# been              20
# made              20
# considered        20
# had               20
# be                18
# used              18
# scheduled         17
# directed by       16
# stars             16
# received          15
# produced by       14
# wrote             14
# hired             14
# introduced in     13
# written by        13
# went              13
# wanted            12
# set               11
# won               11
# began in          11
# began             11
# gave              10
# directed          10
# sold              10
# includes          10
# features           9
# ...

# %% [markdown]
# # Build the Knowledge Graph
#
# Creating a dataframe of entities and predicates

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
kg_df.head()
# Out:
#           source            target          edge
# 0         connie               own       decides
# 1  woman  scream          distance      heard in
# 2      christian       then  elder  paralyzed by
# 3         temple              fire        set on
# 4                 outside cult him    wails with

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %% [markdown]
# Plotting the graph

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# Using only a few relations to visualize the graph.
# "composed by" relationship.

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# Graph for the “written by” relationship.

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# “released in” relationship.

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
